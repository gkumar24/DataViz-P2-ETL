# %%
import pandas as pd

import numpy as py

file_to_load = "Resources/census_data.csv"

census_data = pd.read_csv(file_to_load)

# %%
county_data = census_data.loc[:, ["State", "County", "Income", "TotalPop", "Men", "Women", "Hispanic", "White", "Black", "Native", "Asian", "Pacific", "MeanCommute", "Employed"]]
census_county = census_data["County"].value_counts()
county_income = county_data.groupby(["County", "State"]).mean()["Income"].rename("Mean Income Per County")
county_pop = county_data.groupby(["County", "State"]).sum()["TotalPop"].rename("Total Pop Per County")
county_males = county_data.groupby(["County", "State"]).sum()["Men"].rename("Males Per County")
county_females = county_data.groupby(["County", "State"]).sum()["Women"].rename("Females Per County")
county_w = county_data.groupby(["County", "State"]).mean()["White"].rename("White")
county_b = county_data.groupby(["County", "State"]).mean()["Black"].rename("Black")
county_n = county_data.groupby(["County", "State"]).mean()["Native"].rename("Native")
county_a = county_data.groupby(["County", "State"]).mean()["Asian"].rename("Asian")
county_p = county_data.groupby(["County", "State"]).mean()["Pacific"].rename("Pacific")
county_commute = county_data.groupby(["County", "State"]).mean()["MeanCommute"].rename("MeanCommute")
county_employed = county_data.groupby(["County", "State"]).sum()["Employed"].rename("Employed")
county_analysis = pd.DataFrame({"Mean Income By County":county_income.map("${:,.2f}".format), 
                                "Total Population By County":county_pop.round(), "Male":county_males.round(), 
                                "Female":county_females.round(), "White":county_w.round(), "Black":county_b.round(), 
                                "Native":county_n.round(), "Asian":county_a.round(), "Pacific":county_p.round(), 
                                "Mean Commute":county_commute.round(), "Employed":county_employed.round()})
county_analysis
# Out:
#                                          Mean Income By County  \
# County                    State
# Abbeville                 South Carolina            $35,159.83
# Acadia                    Louisiana                 $39,619.33
# Accomack                  Virginia                  $39,467.00
# Ada                       Idaho                     $59,137.41
# Adair                     Iowa                      $46,859.67
#                           Kentucky                  $32,822.00
#                           Missouri                  $36,419.50
#                           Oklahoma                  $32,869.40
# Adams                     Colorado                  $61,560.12
#                           Idaho                     $37,684.50
#                           Illinois                  $44,731.06
#                           Indiana                   $49,661.57
#                           Iowa                      $48,335.00
# ...

# %%
county_analysis = county_analysis.loc[:, ["Mean Income By County", "Total Population By County", "Male", "Female", "White", "Black", "Native", "Asian", "Pacific", "Mean Commute", "Employed"]]
county_analysis_reset = county_analysis.reset_index()
county_analysis_reset
# Out:
#                          County           State Mean Income By County  \
# 0                     Abbeville  South Carolina            $35,159.83
# 1                        Acadia       Louisiana            $39,619.33
# 2                      Accomack        Virginia            $39,467.00
# 3                           Ada           Idaho            $59,137.41
# 4                         Adair            Iowa            $46,859.67
# 5                         Adair        Kentucky            $32,822.00
# 6                         Adair        Missouri            $36,419.50
# 7                         Adair        Oklahoma            $32,869.40
# 8                         Adams        Colorado            $61,560.12
# 9                         Adams           Idaho            $37,684.50
# 10                        Adams        Illinois            $44,731.06
# 11                        Adams         Indiana            $49,661.57
# ...

# %%
targetcity = pd.read_csv("Resources/TargetCity.csv")
targetcity
# Out:
#                   City      State              City_State_Zip State_Abbr
# 0            Alabaster    Alabama         Alabaster AL 35007          AL
# 1             Bessemer    Alabama          Bessemer AL 35022          AL
# 2           Birmingham    Alabama        Birmingham AL 35235          AL
# 3           Birmingham    Alabama        Birmingham AL 35242          AL
# 4           Birmingham    Alabama        Birmingham AL 35226          AL
# 5               Daphne    Alabama            Daphne AL 36526          AL
# 6              Decatur    Alabama           Decatur AL 35601          AL
# 7               Dothan    Alabama            Dothan AL 36303          AL
# 8             Florence    Alabama          Florence AL 35630          AL
# 9           Fultondale    Alabama        Fultondale AL 35068          AL
# 10         Gulf Shores    Alabama       Gulf Shores AL 36542          AL
# 11            Homewood    Alabama     Homewood AL 35209-4501          AL
# ...

# %%
uscity = pd.read_csv("Resources/uscities.csv")
uscity
# Out:
#                             City                 city_ascii state_id  \
# 0                    South Creek                South Creek       WA
# 1                         Roslyn                     Roslyn       WA
# 2                        Sprague                    Sprague       WA
# 3                     Gig Harbor                 Gig Harbor       WA
# 4                   Lake Cassidy               Lake Cassidy       WA
# 5                         Tenino                     Tenino       WA
# 6                      Jamestown                  Jamestown       WA
# 7                    Three Lakes                Three Lakes       WA
# 8                    Curlew Lake                Curlew Lake       WA
# 9                     Chain Lake                 Chain Lake       WA
# 10                       Pateros                    Pateros       WA
# 11                       Rosburg                    Rosburg       WA
# 12                      Parkland                   Parkland       WA
# ...

# %%
target_counties = pd.merge(targetcity, uscity, how='left', on=['City', 'State'])
target_counties = target_counties.sort_values(by=["County", "State"])
target_counties
# Out:
#                        City           State                   City_State_Zip  \
# 583                   Boise           Idaho                  Boise ID 83713
# 584                   Boise           Idaho                  Boise ID 83704
# 374                Thornton        Colorado               Thornton CO 80233
# 337                  Aurora        Colorado                 Aurora CO 80012
# 338                  Aurora        Colorado                 Aurora CO 80012
# 339                  Aurora        Colorado                 Aurora CO 80016
# 340                  Aurora        Colorado                 Aurora CO 80015
# 341                  Aurora        Colorado                 Aurora CO 80016
# 375             Westminster        Colorado            Westminster CO 80021
# 376             Westminster        Colorado            Westminster CO 80023
# 343                Brighton        Colorado               Brighton CO 80601
# ...

# %%
target_count = target_counties["County"].value_counts()
target_count
# Out:
# Los Angeles                    47
# Orange                         40
# Cook                           35
# Maricopa                       32
# Clark                          21
# Jefferson                      20
# San Diego                      20
# Hennepin                       18
# Montgomery                     18
# Riverside                      17
# Santa Clara                    15
# Harris|Fort Bend|Montgomery    15
# San Bernardino                 15
# Douglas                        15
# Lake                           14
# Washington                     14
# Bexar|Medina                   13
# Broward                        12
# St. Louis                      11
# King                           11
# Hamilton                       11
# Hillsborough                   11
# Wayne                          10
# Middlesex                      10
# Sacramento                     10
# Oakland                        10
# Alameda                        10
# ...

# %%
target_counties_clean = target_counties.loc[:, ["State", "County"]]
target_counties_df = target_counties_clean.set_index(["County"])
target_counties_df["Target Locations By County"] = target_count
target_counties_df
# Out:
#                             State  Target Locations By County
# County
# Ada                         Idaho                         2.0
# Ada                         Idaho                         2.0
# Adams                    Colorado                         1.0
# Adams|Arapahoe           Colorado                         5.0
# Adams|Arapahoe           Colorado                         5.0
# Adams|Arapahoe           Colorado                         5.0
# Adams|Arapahoe           Colorado                         5.0
# Adams|Arapahoe           Colorado                         5.0
# Adams|Jefferson          Colorado                         2.0
# Adams|Jefferson          Colorado                         2.0
# Adams|Weld               Colorado                         1.0
# Aiken              South Carolina                         1.0
# Alachua                   Florida                         1.0
# Alamance|Guilford  North Carolina                         1.0
# ...

# %%
target_census = pd.merge(target_counties_df, county_analysis_reset, how='left', on=['County', 'State'])
target_census = target_census.sort_values(by=["Mean Income By County"])
target_census = target_census.set_index(["County", "State"])
# target_census = target_census.groupby["County"].mean()["Mean Income By County", "Total Population By County", "Male", "Female", "White", "Black", "Native", "Asian", "Pacific", "Mean Commute", "Employed"]
target_census
# Out:
#                                Target Locations By County  \
# County         State
# Santa Clara    California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
#                California                            15.0
# ...

# %%
# target_census2 = pd.merge(target_counties_clean, census_data, how='left', on=['County', 'State'])
# target_census2
