# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# Store filepath in a variable
csv_path = "Resources\census_data.csv"
census_df = pd.read_csv(csv_path)

census_df.head()
# Out:
#    CensusTract    State   County  TotalPop   Men  Women  Hispanic  White  \
# 0   1001020100  Alabama  Autauga      1948   940   1008       0.9   87.4
# 1   1001020200  Alabama  Autauga      2156  1059   1097       0.8   40.4
# 2   1001020300  Alabama  Autauga      2968  1364   1604       0.0   74.5
# 3   1001020400  Alabama  Autauga      4423  2172   2251      10.5   82.8
# 4   1001020500  Alabama  Autauga     10763  4922   5841       0.7   68.5
#
#    Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0    7.7     0.3  ...   0.5          2.3         2.1         25.0       943
# 1   53.3     0.0  ...   0.0          0.7         0.0         23.4       753
# 2   18.6     0.5  ...   0.0          0.0         2.5         19.6      1373
# 3    3.7     1.6  ...   0.0          2.6         1.6         25.3      1782
# 4   24.8     0.0  ...   0.0          0.6         0.9         24.8      5037
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
#Viewing columns to determine the columns that we will be dropping/Extracting from the dataframe
census_df.columns
# Out:
# Index(['CensusTract', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen',
#        'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
#Using loc method to choose columns ww will use for analysis
census_demographics = census_df.loc[:, ["State", "County", "TotalPop", "Men", "Women", "Hispanic", "White", "Black", "Native", "Asian", "Pacific"]]
census_demographics
# Out:
#              State   County  TotalPop   Men  Women  Hispanic  White  Black  \
# 0          Alabama  Autauga      1948   940   1008       0.9   87.4    7.7
# 1          Alabama  Autauga      2156  1059   1097       0.8   40.4   53.3
# 2          Alabama  Autauga      2968  1364   1604       0.0   74.5   18.6
# 3          Alabama  Autauga      4423  2172   2251      10.5   82.8    3.7
# 4          Alabama  Autauga     10763  4922   5841       0.7   68.5   24.8
# ...            ...      ...       ...   ...    ...       ...    ...    ...
# 73996  Puerto Rico    Yauco      6205  3291   2914      99.7    0.3    0.0
# 73997  Puerto Rico    Yauco      2122   921   1201      99.2    0.3    0.0
# 73998  Puerto Rico    Yauco      2277  1097   1180      99.5    0.4    0.0
# 73999  Puerto Rico    Yauco      5267  2663   2604      98.8    1.2    0.0
# 74000  Puerto Rico    Yauco      2741  1181   1560      99.3    0.7    0.0
#
#        Native  Asian  Pacific
# 0         0.3    0.6      0.0
# ...

# %%
#find the date types for the different variables in the table. 
census_demographics.dtypes
# Out:
# State        object
# County       object
# TotalPop      int64
# Men           int64
# Women         int64
# Hispanic    float64
# White       float64
# Black       float64
# Native      float64
# Asian       float64
# Pacific     float64
# dtype: object

# %%
#Groupby County and suming by demographics to have one row for each county.
census_dem = census_demographics.groupby(['State','County']).sum()
census_dem.head()
# Out:
#                  TotalPop    Men  Women  Hispanic   White  Black  Native  \
# State   County
# Alabama Autauga     55221  26745  28476      34.2   877.8  249.9     6.8
#         Baldwin    195121  95314  99807     126.0  2587.1  298.4    18.6
#         Barbour     26932  14497  12435      43.2   419.5  418.4     1.3
#         Bibb        22604  12073  10531       9.9   310.0   70.9     1.8
#         Blount      57710  28512  29198      80.0   790.2   12.2     2.5
#
#                  Asian  Pacific
# State   County
# Alabama Autauga    8.4      0.3
#         Baldwin   20.4      0.0
#         Barbour    3.0      0.0
#         Bibb       0.6      0.0
#         Blount     1.1      0.0

# %%
#Resetting index so that State and County are set to columns. 
census_dem = census_dem.reset_index()

# %%
census_dem
# Out:
#         State      County  TotalPop    Men  Women  Hispanic   White  Black  \
# 0     Alabama     Autauga     55221  26745  28476      34.2   877.8  249.9
# 1     Alabama     Baldwin    195121  95314  99807     126.0  2587.1  298.4
# 2     Alabama     Barbour     26932  14497  12435      43.2   419.5  418.4
# 3     Alabama        Bibb     22604  12073  10531       9.9   310.0   70.9
# 4     Alabama      Blount     57710  28512  29198      80.0   790.2   12.2
# ...       ...         ...       ...    ...    ...       ...     ...    ...
# 3215  Wyoming  Sweetwater     44772  23359  21413     186.3   963.6   11.1
# 3216  Wyoming       Teton     22311  11537  10774      61.9   325.2    0.9
# 3217  Wyoming       Uinta     20930  10636  10294      26.3   263.8    0.5
# 3218  Wyoming    Washakie      8400   4144   4256      42.4   246.5    1.8
# 3219  Wyoming      Weston      7152   3695   3457       6.4   184.5    0.4
#
#       Native  Asian  Pacific
# 0        6.8    8.4      0.3
# ...

# %%
#Importing SqlAlchemy to use import DataFrame into Postgress.
import sqlalchemy
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
#converting to lower_case to match postgres naming conversion for this particular table
census_dem.columns = [t.lower() for t in census_dem.columns]

# %%
#Get connection credentials from config file
from config import username, password
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/TargetCensusDB')
# engine = create_engine(f'postgresql+psycopg2://{username}:{password}@localhost:5432/census_data')
connection = engine.connect()

# %%
#Export Row file to Postgres
engine.execute("delete FROM census_df")
census_df.to_sql('census_df', engine, if_exists='append', index=False)

# %%
#Exporting tranformed file to Postgres. Appending since table heads already exist in Postgres
engine.execute("delete FROM census_race_ethnicity")
census_dem.to_sql('census_race_ethnicity', engine, if_exists='append', index=False)

# %%
# Read title table into dataframe
StoreCount_Select = "SELECT state, county, state_abbr, store_count from target_count_county"
targetCount_byCounty = pd.read_sql(StoreCount_Select, connection)
targetCount_byCounty
# Out:
#          state     county state_abbr  store_count
# 0      Alabama    Autauga         AL            1
# 1      Alabama    Baldwin         AL            2
# 2      Alabama    Calhoun         AL            1
# 3      Alabama    Houston         AL            1
# 4      Alabama  Jefferson         AL            6
# ..         ...        ...        ...          ...
# 610  Wisconsin   Waukesha         WI            6
# 611  Wisconsin  Winnebago         WI            1
# 612  Wisconsin       Wood         WI            1
# 613    Wyoming    Laramie         WY            1
# 614    Wyoming    Natrona         WY            1
#
# [615 rows x 4 columns]

# %%
target_census = pd.merge(targetCount_byCounty, census_dem, how='left', on=['county', 'state'])
target_census
# Out:
#          state     county state_abbr  store_count  totalpop       men  \
# 0      Alabama    Autauga         AL            1   55221.0   26745.0
# 1      Alabama    Baldwin         AL            2  195121.0   95314.0
# 2      Alabama    Calhoun         AL            1  116648.0   56274.0
# 3      Alabama    Houston         AL            1  103534.0   49563.0
# 4      Alabama  Jefferson         AL            6  659026.0  311581.0
# ..         ...        ...        ...          ...       ...       ...
# 610  Wisconsin   Waukesha         WI            6  393873.0  193441.0
# 611  Wisconsin  Winnebago         WI            1  169004.0   85019.0
# 612  Wisconsin       Wood         WI            1   74012.0   36594.0
# 613    Wyoming    Laramie         WY            1   95431.0   47911.0
# 614    Wyoming    Natrona         WY            1   80011.0   40495.0
#
#         women  hispanic   white   black  native  asian  pacific
# ...

# %%
#Export to Postgres
engine.execute("delete FROM target_race_ethnicity_stats")
target_census.to_sql('target_race_ethnicity_stats', engine, if_exists='append', index=False)
